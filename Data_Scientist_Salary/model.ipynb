# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('dataset_cleaned.csv')

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
df.shape
# Out:
# (742, 28)

# %%
df.drop(['Job Title','Salary Estimate', 'Job Description', 'Company Name','job_state' ,'Location','Headquarters', 'Size', 'Type of ownership','Industry', 'Sector', 'Revenue', 'Competitors', 'company_name'], inplace=True, axis=1)

# %%
df.head()
# Out:
#    Rating  Founded  hourly  employer_provided  min_salary  max_salary  \
# 0     3.8     1973       0                  0          53          91
# 1     3.4     1984       0                  0          63         112
# 2     4.8     2010       0                  0          80          90
# 3     3.8     1965       0                  0          56          97
# 4     2.9     1998       0                  0          86         143
#
#    avg_salary  same_state  company_age  python  r  spark  aws  excel
# 0        72.0           0           49       1  0      0    0      1
# 1        87.5           0           38       1  0      0    0      0
# 2        85.0           1           12       1  0      1    0      1
# 3        76.5           1           57       1  0      0    0      0
# 4       114.5           1           24       1  0      0    0      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             742 non-null    float64
#  1   Founded            742 non-null    int64
#  2   hourly             742 non-null    int64
#  3   employer_provided  742 non-null    int64
#  4   min_salary         742 non-null    int64
#  5   max_salary         742 non-null    int64
#  6   avg_salary         742 non-null    float64
#  7   same_state         742 non-null    int64
#  8   company_age        742 non-null    int64
#  9   python             742 non-null    int64
#  10  r                  742 non-null    int64
#  11  spark              742 non-null    int64
#  12  aws                742 non-null    int64
#  13  excel              742 non-null    int64
# dtypes: float64(2), int64(12)
# memory usage: 81.3 KB

# %%
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

models =[]
models.append(('LR', LinearRegression()))
models.append(('DTC', DecisionTreeRegressor()))
models.append(('svr', SVR()))

names=[]
results=[]
for name, model in models:
    kfold = KFold(n_splits=3)
    cv_results = cross_val_score(model, X, y, cv=kfold, scoring='neg_mean_absolute_error')
    results.append(cv_results)
    names.append(names)
    print(name, cv_results.mean(), cv_results.std())
# Out:
# LR -6.688374792214624e-14 1.6894559687368495e-14
# DTC -0.9913232989421444 0.310277824477691
# svr -29.622255968381324 1.2595215946355147

# %%
from sklearn.model_selection import train_test_split
X = df.drop('avg_salary', axis=1)
y = df['avg_salary']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
# we select second best model and increase its accuracy
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

pipe = Pipeline([('scaler', StandardScaler()),
                 ('clf', LinearRegression())])

pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('clf', LinearRegression())])

# %%
preds = pipe.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, preds)
print('MAE', mae)
# Out:
# MAE 2.4311394949998046e-14

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
